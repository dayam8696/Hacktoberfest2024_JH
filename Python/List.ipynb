# %%
marks = [90,100,30]
print(marks)
# Out:
# [90, 100, 30]

# %%
marks = [90,100,30]
print(marks[1])
# Out:
# 100

# %%
marks = [90,100,30]
marks.append(99)
print(marks)
# Out:
# [90, 100, 30, 99]

# %%
marks = [90,100,30]
marks.insert( 0,99)
print(marks)
# Out:
# [99, 90, 100, 30]

# %%
marks = [90,100,30]
marks.insert( 0,99)
print(30 in marks)
# Out:
# True

# %%
marks = [90,100,30]
marks.insert( 0,99)
print(50 in marks)
# Out:
# False

# %%
marks = [90,100,30]
marks.insert( 0,99)
print(len(marks))
# Out:
# 4

# %%
marks = [90,100,30]
i = 0
while i< len(marks):
    print(marks[i])
    i = i+1
# Out:
# 90
# 100
# 30

# %%
marks.clear()
print(marks)
# Out:
# []
