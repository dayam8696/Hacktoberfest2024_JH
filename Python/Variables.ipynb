# %%
var =  10

# %%
var
# Out:
# 10

# %%
var = 20

# %%
var
# Out:
# 20

# %%
var_1 =  30

# %%
var_1
# Out:
# 30

# %% [markdown]
# # Arthemetic Operator using variable

# %%
x = 2
y = 3

# %%
x+y
# Out:
# 5

# %%
y-x
# Out:
# 1

# %%
y/x
# Out:
# 1.5

# %%
y%x
# Out:
# 1

# %%
y*x
# Out:
# 6

# %%
pow(x,y)
# Out:
# 8
